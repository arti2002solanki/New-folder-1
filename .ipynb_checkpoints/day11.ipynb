# %%
#cv2 take bgr not rgb picture
#constant written in captial
#function camel case
#captial camel case Class
import cv2

# %%
import matplotlib.pyplot as plt
import skimage as ski

# %%
vid=cv2.VideoCapture(0)

# %%
type(vid)
# Out:
# cv2.VideoCapture

# %%
vid.isOpened()
# Out:
# True

# %%
k=vid.read()

# %%
type(k),len(k)
# Out:
# (tuple, 2)

# %%
k
# Out:
# (True,
#  array([[[147, 112, 154],
#          [130, 106, 152],
#          [206, 192, 243],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[145, 112, 156],
#          [132, 108, 156],
#          [207, 193, 244],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[114,  88, 152],
#          [129, 110, 168],
#          [204, 191, 245],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[ 27,  58,  62],
#          [ 45,  59,  66],
#          [ 65,  63,  72],
#          ...,
#          [156, 123, 102],
#          [155, 123, 103],
#          [150, 118,  99]],
#
#         [[ 35,  58,  67],
#          [ 46,  57,  67],
#          [ 70,  67,  79],
#          ...,
#          [156, 123, 102],
#          [157, 128, 108],
#          [157, 128, 108]],
#
#         [[ 37,  55,  76],
# ...

# %%
flag,img=vid.read()

# %%
if flag:
    plt.imshow(img[:,:,::-1])

# %%
# img.shape
# img[:,:,::-1]
# Out:
# array([[[253, 255, 255],
#         [253, 255, 255],
#         [253, 255, 255],
#         ...,
#         [253, 255, 255],
#         [253, 255, 255],
#         [253, 255, 255]],
#
#        [[253, 255, 255],
#         [253, 255, 255],
#         [253, 255, 255],
#         ...,
#         [253, 255, 255],
#         [253, 255, 255],
#         [253, 255, 255]],
#
#        [[253, 255, 255],
#         [253, 255, 255],
#         [253, 255, 255],
#         ...,
#         [253, 255, 255],
#         [253, 255, 255],
#         [253, 255, 255]],
#
#        ...,
#
#        [[100,  90,  58],
#         [100,  91,  62],
#         [103,  96,  70],
#         ...,
#         [ 85, 133, 154],
#         [ 82, 130, 149],
#         [ 80, 129, 147]],
#
#        [[ 91,  93,  56],
#         [ 92,  92,  56],
#         [ 94,  93,  59],
#         ...,
#         [ 80, 133, 155],
#         [ 69, 129, 151],
#         [ 71, 131, 154]],
#
#        [[ 93,  92,  56],
#         [ 93,  92,  54],
#         [ 97,  95,  59],
# ...

# %%
for i in range(100):
    flag,img=vid.read()
    if flag:
        plt.imshow(img[:,:,::-1])

# %%
for i in range(1000):
    flag,img=vid.read()
    if flag:
        cv2.imshow('preview',img)
        cv2.waitKey(1)

# %%
#ord is used to find ascii value
ord('A')
# Out:
# 65

# %%
vid=cv2.VideoCapture(0)
while True:
    flag,img=vid.read()
    if flag:
        cv2.imshow('preview',img)
        key=cv2.waitKey(1)
        if key == ord('q'):
            break
    else:
        break
vid.release()            
cv2.destroyAllWindows()

# %%
vid=cv2.VideoCapture(0)
while True:
    flag, img = vid.read()
    if flag:
        #processing code
        img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        th,img_bw=cv2.threshold(img_gray,50,25,cv2.THRESH_BINARY_INV)

        cv2.imshow('preview',img_bw)
        key=cv2.waitKey(1)
        if key == ord('q'):
            break
    else:
        print('No frames')
        break
vid.release()            
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from time import sleep

fd = cv2.CascadeClassifier(
    cv2.data.haarcascades+'haarcascade_frontalface_default.xml')
sd=cv2.CascadeClassifier(
    cv2.data.haarcascades+'haarcascade_smile.xml')
e=cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_eye.xml')
vid=cv2.VideoCapture(0)
vid.release()
del vid
vid=cv2.VideoCapture(0)
while True:
    flag, img = vid.read()
    if flag:
        img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        smiles=sd.detectMultiScale(img_gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize(50,50)
        )
        faces=fd.detectMultiScale(img_gray,1.1,5)
        #img_gray,
        #scaleFactor = 1.1,
        #minNeighbors = 5,
        #minSize = (50,50)
        np.random.seed(50)
        colors = np.random.randint(0,255, (len(faces),3)).tolist()
       # colors = [np.random.randint(0,255,3).tolist()
                       #for i in faces]
        i=0
        for x,,y,w,h in faces:
            face=img_gray[y:y+h,x:x+w].copy()
            smiles =sd.detectMultiScale(
                face,
                scaleFactor=1.1,
                minNeighbors=5,
                minSize(50,50)
            )
            if len(smiles)==1
                cv2.imwrite('myselfie.png',img)   
                      
            cv2.rectangle(
            img,pt1=(x,y),pt2=(x+w,y+h),color=colors[i],thickness=8
            )
            i+=1

        cv2.imwrite('myselfie.png',img)     
        cv2.imshow('Preview',img)
        key=cv2.waitKey(1)
        if key==ord('q'):
            break
    else:
        print('No frames')
        break
    sleep(0.1)
               
cv2.destroyAllWindows()  
vid.release() 
#cv2 i am write(used for save the picture)
# Out:
#   Cell In[5], line 22
#     )
#     ^
# SyntaxError: positional argument follows keyword argument
